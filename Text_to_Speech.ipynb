# %%
pip install gtts
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from gtts import gTTS
from IPython.display import Audio

text_to_speech = gTTS('''Welcome to naresh technology data science programme under prakash senapati guidance.
                         classes will help practicle exposure to boost up technical skill
                         and increase learning for coding skills. we conduct this programme for
                         both non-technical and technical learners. Thank you.''',lang='hi',tld='com')

text_to_speech.save('text_to_speech_gtts.wav')
sound_file = 'text_to_speech_gtts.wav'

Audio(sound_file, autoplay = False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
pip install pyttsx3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyttsx3
from IPython.display import Audio

text = '''Welcome to naresh technology datascience programme under prakash senapati guidance
          trainig will help practicle exposure to boost up techanical skill
          and increase learning for coding skills.
          we conduct this programme for both non-technical & techanical learners. Thank you.'''

audio = pyttx3.init()
audio.setProperty('rate', 150)
audio.setProperty('volume', 0.8)

voice = audio.getProperty('voices')
audio.setProperty('voice', voice[0].id)

audio.say(text)

audio.save_to_file(text, 'test_male_Voice.mp3')

audio.runAndWait()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 9
#       2 from IPython.display import Audio
#       4 text = '''Welcome to naresh technology datascience programme under prakash senapati guidance
#       5           trainig will help practicle exposure to boost up techanical skill
#       6           and increase learning for coding skills.
#       7           we conduct this programme for both non-technical & techanical learners. Thank you.'''
# ----> 9 audio = pyttx3.init()
#      10 audio.setProperty('rate', 150)
#      11 audio.setProperty('volume', 0.8)
#
# NameError: name 'pyttx3' is not defined
