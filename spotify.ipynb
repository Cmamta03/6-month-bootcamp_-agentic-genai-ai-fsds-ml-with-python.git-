# %% [markdown]
# <a href="https://colab.research.google.com/github/Cmamta03/6-month-bootcamp_-agentic-genai-ai-fsds-ml-with-python.git-/blob/main/spotify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import os
for dirname,  _, filenames in os.walk('/kaggle/input'):
  for filename in filenames:
    print(os.path.join(dirname, filename))

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/spotify_data clean.csv")
df
# Out:
#                     track_id                                       track_name  \
# 0     3EJS5LyekDim1Tf5rBFmZl                    Trippy Mane (ft. Project Pat)
# 1     1oQW6G2ZiwMuHqlPpP27DB                                             OMG!
# 2     7mdkjzoIYlf1rx9EtBpGmU                                      Hard 2 Find
# 3     67rW0Zl7oB3qEpD5YWWE5w  Still Get Like That (ft. Project Pat & Starrah)
# 4     15xptTfRBrjsppW0INUZjf                            ride me like a harley
# ...                      ...                                              ...
# 8577  0AQquaENerGps8BQmbPw14                                         Big Iron
# 8578  4f8hBeMXMvssn6HtFAtblo                                          El Paso
# 8579  0Vy7wsXNFrbNc6UTWoScnM                                 Over the Rainbow
# 8580  760clbeDBWmBsBLbszWuNZ                                        I'm A Man
# 8581  61GEP8lryEfcuEgBMbRmNi                               Alone And Forsaken
#
# ...

# %%
df.head()
# Out:
#                  track_id                                       track_name  \
# 0  3EJS5LyekDim1Tf5rBFmZl                    Trippy Mane (ft. Project Pat)
# 1  1oQW6G2ZiwMuHqlPpP27DB                                             OMG!
# 2  7mdkjzoIYlf1rx9EtBpGmU                                      Hard 2 Find
# 3  67rW0Zl7oB3qEpD5YWWE5w  Still Get Like That (ft. Project Pat & Starrah)
# 4  15xptTfRBrjsppW0INUZjf                            ride me like a harley
#
#    track_number  track_popularity  explicit artist_name  artist_popularity  \
# 0             4                 0      True       Diplo                 77
# 1             1                 0      True    Yelawolf                 64
# 2             1                 4      True   Riff Raff                 48
# 3             8                30      True       Diplo                 77
# 4             2                 0      True     Rumelis                 48
#
#    artist_followers                      artist_genres  \
# ...

# %%
df.columns
# Out:
# Index(['track_id', 'track_name', 'track_number', 'track_popularity',
#        'explicit', 'artist_name', 'artist_popularity', 'artist_followers',
#        'artist_genres', 'album_id', 'album_name', 'album_release_date',
#        'album_total_tracks', 'album_type', 'track_duration_min'],
#       dtype='object')

# %%
df.tail()
# Out:
#                     track_id          track_name  track_number  \
# 8577  0AQquaENerGps8BQmbPw14            Big Iron             1
# 8578  4f8hBeMXMvssn6HtFAtblo             El Paso            10
# 8579  0Vy7wsXNFrbNc6UTWoScnM    Over the Rainbow             5
# 8580  760clbeDBWmBsBLbszWuNZ           I'm A Man             2
# 8581  61GEP8lryEfcuEgBMbRmNi  Alone And Forsaken            11
#
#       track_popularity  explicit    artist_name  artist_popularity  \
# 8577                71     False  Marty Robbins                 60
# 8578                64     False  Marty Robbins                 61
# 8579                 8     False    The Mystics                 27
# 8580                55     False     Bo Diddley                 44
# 8581                45     False  Hank Williams                 55
#
#       artist_followers                                      artist_genres  \
# 8577            626733                    classic country, outlaw country
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8582 entries, 0 to 8581
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   track_id            8582 non-null   object
#  1   track_name          8582 non-null   object
#  2   track_number        8582 non-null   int64
#  3   track_popularity    8582 non-null   int64
#  4   explicit            8582 non-null   bool
#  5   artist_name         8579 non-null   object
#  6   artist_popularity   8582 non-null   int64
#  7   artist_followers    8582 non-null   int64
#  8   artist_genres       5221 non-null   object
#  9   album_id            8582 non-null   object
#  10  album_name          8582 non-null   object
#  11  album_release_date  8582 non-null   object
#  12  album_total_tracks  8582 non-null   int64
#  13  album_type          8582 non-null   object
#  14  track_duration_min  8582 non-null   float64
# ...

# %%
df["album_release_date"]=pd.to_datetime(df["album_release_date"], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8582 entries, 0 to 8581
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   track_id            8582 non-null   object
#  1   track_name          8582 non-null   object
#  2   track_number        8582 non-null   int64
#  3   track_popularity    8582 non-null   int64
#  4   explicit            8582 non-null   bool
#  5   artist_name         8579 non-null   object
#  6   artist_popularity   8582 non-null   int64
#  7   artist_followers    8582 non-null   int64
#  8   artist_genres       5221 non-null   object
#  9   album_id            8582 non-null   object
#  10  album_name          8582 non-null   object
#  11  album_release_date  8582 non-null   datetime64[ns]
#  12  album_total_tracks  8582 non-null   int64
#  13  album_type          8582 non-null   object
#  14  track_duration_min  8582 non-null   float64
# ...

# %%
df
# Out:
#                     track_id                                       track_name  \
# 0     3EJS5LyekDim1Tf5rBFmZl                    Trippy Mane (ft. Project Pat)
# 1     1oQW6G2ZiwMuHqlPpP27DB                                             OMG!
# 2     7mdkjzoIYlf1rx9EtBpGmU                                      Hard 2 Find
# 3     67rW0Zl7oB3qEpD5YWWE5w  Still Get Like That (ft. Project Pat & Starrah)
# 4     15xptTfRBrjsppW0INUZjf                            ride me like a harley
# ...                      ...                                              ...
# 8577  0AQquaENerGps8BQmbPw14                                         Big Iron
# 8578  4f8hBeMXMvssn6HtFAtblo                                          El Paso
# 8579  0Vy7wsXNFrbNc6UTWoScnM                                 Over the Rainbow
# 8580  760clbeDBWmBsBLbszWuNZ                                        I'm A Man
# 8581  61GEP8lryEfcuEgBMbRmNi                               Alone And Forsaken
#
# ...

# %%
df.describe()
# Out:
#        track_number  track_popularity  artist_popularity  artist_followers  \
# count   8582.000000       8582.000000        8582.000000      8.582000e+03
# mean       5.772547         52.356211          69.730016      2.403472e+07
# min        1.000000          0.000000           0.000000      0.000000e+00
# 25%        1.000000         39.000000          60.000000      4.623200e+05
# 50%        4.000000         58.000000          74.000000      6.105547e+06
# 75%        9.000000         71.000000          84.000000      2.725255e+07
# max      102.000000         99.000000         100.000000      1.455421e+08
# std        6.052792         23.816076          19.645979      3.803180e+07
#
#                   album_release_date  album_total_tracks  track_duration_min
# count                           8582         8582.000000         8582.000000
# mean   2015-07-21 16:44:54.756466944           13.789443            3.492805
# ...

# %%
df.describe(include="O")
# Out:
#                       track_id track_name   artist_name artist_genres  \
# count                     8582       8582          8579          5221
# unique                    8582       7462          2547           661
# top     61GEP8lryEfcuEgBMbRmNi    Flowers  Taylor Swift    soundtrack
# freq                         1          8           324           345
#
#                       album_id                        album_name album_type
# count                     8582                              8582       8582
# unique                    5205                              4870          3
# top     3FFGbUutKWN1c4f0CJR4Uh  Nevermind (Super Deluxe Edition)      album
# freq                        70                                70       5856

# %%
df.isna().sum()
# Out:
# track_id                 0
# track_name               0
# track_number             0
# track_popularity         0
# explicit                 0
# artist_name              3
# artist_popularity        0
# artist_followers         0
# artist_genres         3361
# album_id                 0
# album_name               0
# album_release_date       0
# album_total_tracks       0
# album_type               0
# track_duration_min       0
# dtype: int64

# %%
df1 = df.dropna(subset=["track_name", "artist_name", "album_release_date"])

# %%
df1.isna().sum()
# Out:
# track_id                 0
# track_name               0
# track_number             0
# track_popularity         0
# explicit                 0
# artist_name              0
# artist_popularity        0
# artist_followers         0
# artist_genres         3358
# album_id                 0
# album_name               0
# album_release_date       0
# album_total_tracks       0
# album_type               0
# track_duration_min       0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
df1["track_popularity"].agg(["min", "max", "mean"])
# Out:
# min      0.000000
# max     99.000000
# mean    52.355519
# Name: track_popularity, dtype: float64

# %%
df1[df1["track_popularity"]==100.000000]
# Out:
# Empty DataFrame
# Columns: [track_id, track_name, track_number, track_popularity, explicit, artist_name, artist_popularity, artist_followers, artist_genres, album_id, album_name, album_release_date, album_total_tracks, album_type, track_duration_min]
# Index: []
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# ...

# %%
df[df["track_popularity"]==0.000000]
# Out:
#                     track_id                      track_name  track_number  \
# 0     3EJS5LyekDim1Tf5rBFmZl   Trippy Mane (ft. Project Pat)             4
# 1     1oQW6G2ZiwMuHqlPpP27DB                            OMG!             1
# 4     15xptTfRBrjsppW0INUZjf           ride me like a harley             2
# 13    6zFWxD9hkOPAIlgWAGyQGQ                      Let’s Go!!             2
# 596   3XbsJyWT7pwLh8XUr2fSOV                    Lollapalooza             1
# ...                      ...                             ...           ...
# 8376  7J87u2pUI0xBt8HVKNuJ8n               Yesterday Is Here             7
# 8469  4Anmaai9xAsuhCc6Kl7qWM                    Cantina Band             9
# 8492  5EBoNoVE7BoGQ7Hfd2uGUR  Don't Let Me Down - Remastered             5
# 8561  7hc9InDMML0NwWNPoK49AR                     La condanna            22
# 8565  4Wzt8Dm4xpO3LjWDecP4bA                 She's Not There             7
#
# ...

# %%
df1
# Out:
#                     track_id                                       track_name  \
# 0     3EJS5LyekDim1Tf5rBFmZl                    Trippy Mane (ft. Project Pat)
# 1     1oQW6G2ZiwMuHqlPpP27DB                                             OMG!
# 2     7mdkjzoIYlf1rx9EtBpGmU                                      Hard 2 Find
# 3     67rW0Zl7oB3qEpD5YWWE5w  Still Get Like That (ft. Project Pat & Starrah)
# 4     15xptTfRBrjsppW0INUZjf                            ride me like a harley
# ...                      ...                                              ...
# 8577  0AQquaENerGps8BQmbPw14                                         Big Iron
# 8578  4f8hBeMXMvssn6HtFAtblo                                          El Paso
# 8579  0Vy7wsXNFrbNc6UTWoScnM                                 Over the Rainbow
# 8580  760clbeDBWmBsBLbszWuNZ                                        I'm A Man
# 8581  61GEP8lryEfcuEgBMbRmNi                               Alone And Forsaken
#
# ...

# %%
artist_name=df1.pivot_table(index="artist_name", values="artist_followers", aggfunc=["min", "max", "mean"])
artist_name
# Out:
#                               min              max             mean
#                  artist_followers artist_followers artist_followers
# artist_name
# $uicideboy$               8957416          8957416        8957416.0
# 'Ery Noice                  11720            11720          11720.0
# (((())))                    49519            49519          49519.0
# *NSYNC                    3088613          3088613        3088613.0
# -                             714              714            714.0
# ...                           ...              ...              ...
# 攬佬SKAI ISYOURGOD           298654           298654         298654.0
# 時瀬高等学校箏曲部                    2625             2625           2625.0
# 桑原まこ                          346              346            346.0
# 梶浦 由記                      132111           132111         132111.0
# 藤澤慶昌                        13564            13575          13569.5
#
# [2547 rows x 3 columns]

# %%
track_name=df1.pivot_table(index="track_name", values="track_popularity", aggfunc=["min", "max", "mean"])
track_name
# Out:
#                                                                 min  \
#                                                    track_popularity
# track_name
# !!!!!!!                                                          17
# "In The Hall Of The Mountain King" from Peer Gy...               52
# #GETITRIGHT                                                      44
# #thatPOWER                                                       67
# &burn (with Vince Staples)                                       56
# ...                                                             ...
# 臨界                                                               34
# 英雄                                                               27
# 落葉船                                                              38
# 道は続く                                                             38
# 銀髪の少年                                                             0
#
# ...

# %%
album_type=df1.pivot_table(index="album_type", values="track_popularity", aggfunc=["min","max","mean"])
album_type
# Out:
#                          min              max             mean
#             track_popularity track_popularity track_popularity
# album_type
# album                      0               99        55.653459
# compilation                0               82        40.512821
# single                     0               95        46.354082

# %%
album_name=df1.pivot_table(index="album_name",values="album_total_tracks", aggfunc=["min","max","mean"])
album_name
# Out:
#                                                  min                max  \
#                                   album_total_tracks album_total_tracks
# album_name
# #000000 & #FFFFFF (No DJ Version)                 16                 16
# #1s ... and then some                             30                 30
# #3                                                10                 10
# #3 Deluxe Version                                 17                 17
# #willpower                                        15                 15
# ...                                              ...                ...
# この音とまれ!～時瀬高等学校箏曲部～                                12                 12
# ソードアート・オンライン ミュージックコレクション                        131                131
# 七つの大罪 オリジナル・サウンドトラック 2                            25                 25
# 八方來財(Stacks from All Sides)                       19                 19
# 千と千尋の神隠し サウンドトラック                                 21                 21
#
# ...
